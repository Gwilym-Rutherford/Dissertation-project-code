# %% [markdown]
# # DMO features to Fatigue

# %%
from src.patient_data_dispatcher import PatientDataDispatcher, PatientDataType
from src.model import DMOLSTM
from src.core.enums import MileStone
from src.core.data_transforms import Transform
from src.train import TrainRegression
from torchmetrics.regression import R2Score

import matplotlib.pyplot as plt

import numpy as np
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
dmo_features = [
    "cadence_30_p90_d",
    "cadence_30_avg_d",
    "ws_30_p90_d",
    "strlen_1030_avg_d",
    "cadence_all_avg_d",
]

# %%
pdd = PatientDataDispatcher("config/config.yaml", dmo_features, MileStone.ALL)
ids = list(set(pdd.metadata["Local.Participant"].to_list()))
dmo_data, dmo_labels = pdd.get_patient_data(PatientDataType.MILESTONE, ids=ids)

# %%
# remove patients that don't have a full dataset
patient_indexs = []
patient, visit, day, features = dmo_data.shape
for p in range(patient):
    all_visits = True
    for v in range(visit):
        data = dmo_data[p, v]
        label = dmo_labels[p, v]
        if (data == -1.0).any() or label == -1.0:
            all_visits = False

    if all_visits:
        patient_indexs.append(p)

dmo_data = dmo_data[patient_indexs]
dmo_labels = dmo_labels[patient_indexs]

# %%
from src.model import lstm_regression
config = lstm_regression
config.notes = "None"

# %%
predicted_values = []
actual_values = []

n_patients, n_visit, n_day, n_features = dmo_data.shape
for patient_index in range(n_patients):
    print(f"X Validation {patient_index}")

    # split data
    train_indexes = [i for i in range(n_patients) if i != patient_index]
    train_data = dmo_data[train_indexes].squeeze(dim=0)
    train_label = dmo_labels[train_indexes]

    test_data = dmo_data[patient_index]
    test_label = dmo_labels[patient_index].unsqueeze(dim=0)

    transform = Transform()

    # fit and transform scaler on training data only, then transform testing
    train_data = transform.fit_transform_dmo_data(train_data)
    test_data = transform.transform_dmo_data(test_data)

    # fit and transform scaler on training labels, then transform testing labels
    train_label = transform.fit_transform_dmo_labels(train_label)
    test_label = transform.transform_dmo_labels(test_label)

    # convert to tensors
    train_data = torch.from_numpy(train_data)
    train_label = torch.from_numpy(train_label)

    test_data = torch.from_numpy(test_data)
    test_label = torch.from_numpy(test_label)

    # format data
    train_data = Transform.format_input_data_time_seq_days(train_data)
    test_data = Transform.format_input_data_time_seq_days(test_data)

    train_label = Transform.format_label_time_seq_visit(train_label)
    test_label = Transform.format_label_time_seq_visit(test_label)

    # Convert to dataloaders
    training_dataloader = Transform.data_to_dataloaders(
        train_data, train_label, batch_size=16
    )
    testing_dataloader = Transform.data_to_dataloaders(
        test_data, test_label, batch_size=16
    )

    # reinstantiate model every loop for x validation
    model = DMOLSTM(config).to(device=device)
    optimiser = config.optimiser(model.parameters(), lr=config.learning_rate)

    trainer = TrainRegression(
        model,
        optimiser,
        config,
        training_dataloader,
        testing_dataloader,
        device,
        verbose=True,
    )

    trainer.train_loop(label_transform=lambda x: x.squeeze(dim=0))
    prediction, actual = trainer.test_loop(label_transform=lambda x: x.squeeze(dim=0))

    predicted_values += prediction
    actual_values += actual
# Out:
# X Validation 0
# Testing loss: 0.020406289026141167
# X Validation 1
# Testing loss: 0.008424649946391582
# X Validation 2
# Testing loss: 0.05027799680829048
# X Validation 3
# Testing loss: 0.019520167261362076
# X Validation 4
# Testing loss: 0.08413691073656082
# X Validation 5
# Testing loss: 0.00442356476560235
# X Validation 6
# Testing loss: 0.007529711816459894
# X Validation 7
# Testing loss: 0.0400414876639843
# X Validation 8
# Testing loss: 0.03270931914448738
# X Validation 9
# Testing loss: 0.0019789026118814945
# X Validation 10
# Testing loss: 0.06717969477176666
# X Validation 11
# Testing loss: 0.029971003532409668
# X Validation 12
# Testing loss: 0.0026577175594866276
# X Validation 13
# Testing loss: 0.1228262186050415
# X Validation 14
# Testing loss: 0.02668844163417816
# X Validation 15
# Testing loss: 0.056359149515628815
# X Validation 16
# Testing loss: 0.03701385483145714
# X Validation 17
# Testing loss: 0.018270496279001236
# X Validation 18
# Testing loss: 0.0718047246336937
# X Validation 19
# Testing loss: 0.03203060105443001
# X Validation 20
# Testing loss: 0.06774356216192245
# X Validation 21
# Testing loss: 0.013593978248536587
# X Validation 22
# Testing loss: 0.025446489453315735
# X Validation 23
# Testing loss: 0.038739558309316635
# X Validation 24
# Testing loss: 0.04474043473601341
# X Validation 25
# Testing loss: 0.04611312225461006
# X Validation 26
# Testing loss: 0.020439637824892998
# X Validation 27
# Testing loss: 0.006136036477982998
# X Validation 28
# Testing loss: 0.032345905900001526
# X Validation 29
# Testing loss: 0.023748984560370445
# X Validation 30
# Testing loss: 0.027425188571214676
# X Validation 31
# Testing loss: 0.006563777569681406
# X Validation 32
# Testing loss: 0.05541442707180977
# X Validation 33
# Testing loss: 0.04119149595499039
# X Validation 34
# Testing loss: 0.2132018655538559
# X Validation 35
# Testing loss: 0.008626825176179409
# X Validation 36
# Testing loss: 0.03334503248333931
# X Validation 37
# Testing loss: 0.05301950126886368
# X Validation 38
# Testing loss: 0.08780758827924728
# X Validation 39
# Testing loss: 0.0009184249793179333
# X Validation 40
# Testing loss: 0.08166059106588364
# X Validation 41
# Testing loss: 0.04121473804116249
# X Validation 42
# Testing loss: 0.06772943586111069
# X Validation 43
# Testing loss: 0.014959679916501045
# X Validation 44
# Testing loss: 0.018998144194483757
# X Validation 45
# Testing loss: 0.24497413635253906
# X Validation 46
# Testing loss: 0.013452532701194286
# X Validation 47
# Testing loss: 0.028487304225564003
# X Validation 48
# Testing loss: 0.010764081962406635
# X Validation 49
# Testing loss: 0.0884237214922905
# X Validation 50
# Testing loss: 0.0015216413885354996
# X Validation 51
# Testing loss: 0.045246172696352005
# X Validation 52
# Testing loss: 0.02973434142768383
# X Validation 53
# Testing loss: 0.016921130940318108
# X Validation 54
# Testing loss: 0.057668961584568024
# X Validation 55
# Testing loss: 0.16038113832473755
# X Validation 56
# Testing loss: 0.006412412505596876
# X Validation 57
# Testing loss: 0.13389217853546143
# X Validation 58
# Testing loss: 0.13946735858917236
# X Validation 59
# Testing loss: 0.01429858710616827
# X Validation 60
# Testing loss: 0.002681176410987973
# X Validation 61
# Testing loss: 0.14315038919448853
# X Validation 62
# Testing loss: 0.015201288275420666
# X Validation 63
# Testing loss: 0.02548283338546753
# X Validation 64
# Testing loss: 0.0495535172522068
# X Validation 65
# Testing loss: 0.03491522744297981
# X Validation 66
# Testing loss: 0.011766485869884491
# X Validation 67
# Testing loss: 0.12535536289215088
# X Validation 68
# Testing loss: 0.045402269810438156
# X Validation 69
# Testing loss: 0.13565491139888763
# X Validation 70
# Testing loss: 0.02546355128288269
# X Validation 71
# Testing loss: 0.04139579087495804
# X Validation 72
# Testing loss: 0.09580620378255844
# X Validation 73
# Testing loss: 0.027369672432541847
# X Validation 74
# Testing loss: 0.011283091269433498
# X Validation 75
# Testing loss: 0.0542323961853981
# X Validation 76
# Testing loss: 0.033328939229249954
# X Validation 77
# Testing loss: 0.18588006496429443
# X Validation 78
# Testing loss: 0.07600787281990051
# X Validation 79
# Testing loss: 0.22147956490516663
# X Validation 80
# Testing loss: 0.005008395295590162
# X Validation 81
# Testing loss: 0.040642913430929184
# X Validation 82
# Testing loss: 0.043314285576343536
# X Validation 83
# Testing loss: 0.019211547449231148
# X Validation 84
# Testing loss: 0.026760656386613846
# X Validation 85
# Testing loss: 0.011597021482884884

# %%
from src.evaluation import Evaluation
import matplotlib.pyplot as plt

actual_values = torch.Tensor(actual_values)
predicted_values = torch.Tensor(predicted_values)

evaluation = Evaluation(predicted_values, actual_values)
print(f"All metrics: {evaluation.compute_all_metrics()}")
evaluation.evaluation_plot().show()
# Out:
# All metrics: {'accuracy': 0.32558139534883723, 'Mean Squared Error': 0.04583654925227165, 'Mean Absolute Error': 0.17707693576812744, 'R^2': 0.09690302610397339}
