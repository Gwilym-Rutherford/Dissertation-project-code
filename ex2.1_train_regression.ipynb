# %%
from src.patient_data_dispatcher import PatientDataDispatcher, PatientDataType
from src.model import DMOLSTM
from src.core.enums import MileStone
from src.core.data_transforms import Transform
from src.train import TrainRegression
from torchmetrics.regression import R2Score

import matplotlib.pyplot as plt

import numpy as np
import torch

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
dmo_features = [
    "cadence_30_p90_d",
    "cadence_30_avg_d",
    "ws_30_p90_d",
    "strlen_1030_avg_d",
    "cadence_all_avg_d",
]

# %%
pdd = PatientDataDispatcher("config/config.yaml", dmo_features, MileStone.ALL)
ids = list(set(pdd.metadata["Local.Participant"].to_list()))
dmo_data, dmo_labels = pdd.get_patient_data(PatientDataType.MILESTONE, ids=ids)

# %%
# remove patients that don't have a full dataset
patient_indexs = []
patient, visit, day, features = dmo_data.shape
for p in range(patient):
    all_visits = True
    for v in range(visit):
        data = dmo_data[p, v]
        label = dmo_labels[p, v]
        if (data == -1.0).any() or label == -1.0:
            all_visits = False

    if all_visits:
        patient_indexs.append(p)

dmo_data = dmo_data[patient_indexs]
dmo_labels = dmo_labels[patient_indexs]

# %%
from src.model import lstm_regression
config = lstm_regression
config.notes = "None"

# %%
predicted_values = []
actual_values = []

n_patients, n_visit, n_day, n_features = dmo_data.shape
for patient_index in range(n_patients):
    print(f"X Validation {patient_index}")

    # split data
    train_indexes = [i for i in range(n_patients) if i != patient_index]
    train_data = dmo_data[train_indexes].squeeze(dim=0)
    train_label = dmo_labels[train_indexes]

    test_data = dmo_data[patient_index]
    test_label = dmo_labels[patient_index].unsqueeze(dim=0)

    transform = Transform()

    # fit and transform scaler on training data only, then transform testing
    train_data = transform.fit_transform_dmo_data(train_data)
    test_data = transform.transform_dmo_data(test_data)

    # fit and transform scaler on training labels, then transform testing labels
    train_label = transform.fit_transform_dmo_labels(train_label)
    test_label = transform.transform_dmo_labels(test_label)

    # convert to tensors
    train_data = torch.from_numpy(train_data)
    train_label = torch.from_numpy(train_label)
    train_label = train_label.reshape(-1, train_label.size(2))

    test_data = torch.from_numpy(test_data)
    test_label = torch.from_numpy(test_label)
    test_label = test_label.reshape(-1, test_label.size(2))


    # format data
    train_data = Transform.format_input_data_only_label(train_label)
    test_data = Transform.format_input_data_only_label(test_label)

    # Convert to dataloaders
    training_dataloader = Transform.data_to_dataloaders(
        train_data, train_label, batch_size=16
    )
    testing_dataloader = Transform.data_to_dataloaders(
        test_data, test_label, batch_size=16
    )

    # reinstantiate model every loop for x validation
    model = DMOLSTM(config).to(device=device)
    optimiser = config.optimiser(model.parameters(), lr=config.learning_rate)

    trainer = TrainRegression(
        model,
        optimiser,
        config,
        training_dataloader,
        testing_dataloader,
        device,
        verbose=True,
    )

    def label_transform(x):

        x = x[:, 4, 0]
        return x


    trainer.train_loop(pred_transform=lambda x: print(x.shape))
    prediction, actual = trainer.test_loop()

    predicted_values += prediction
    actual_values += actual
# Out:
# X Validation 0
# torch.Size([1])
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 68
#      64     x = x[:, 4, 0]
#      65     return x
# ---> 68 trainer.train_loop(pred_transform=lambda x: print(x.shape))
#      69 prediction, actual = trainer.test_loop()
#      71 predicted_values += prediction
#
# File ~/Documents/Year 3 Tuos/dissertation/Workspace/Experiment 1/src/train/train_regression.py:49, in TrainRegression.train_loop(self, label_transform, data_transform, pred_transform)
#      46 if pred_transform:
#      47     pred = pred_transform(pred)
# ---> 49 loss = self.config.loss_fn(pred, label)
#      50 training_loss.append(loss.item())
#      52 loss.backward()
#
# File ~/Documents/Year 3 Tuos/dissertation/Workspace/Experiment 1/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1776, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1774     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1775 else:
# -> 1776     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Year 3 Tuos/dissertation/Workspace/Experiment 1/.venv/lib/python3.13/site-packages/torch/nn/modules/module.py:1787, in Module._call_impl(self, *args, **kwargs)
#    1782 # If we don't have any hooks, we want to skip the rest of the logic in
#    1783 # this function, and just call forward.
#    1784 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1785         or _global_backward_pre_hooks or _global_backward_hooks
#    1786         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1787     return forward_call(*args, **kwargs)
#    1789 result = None
#    1790 called_always_called_hooks = set()
#
# File ~/Documents/Year 3 Tuos/dissertation/Workspace/Experiment 1/.venv/lib/python3.13/site-packages/torch/nn/modules/loss.py:626, in MSELoss.forward(self, input, target)
#     622 def forward(self, input: Tensor, target: Tensor) -> Tensor:
#     623     """
#     624     Runs the forward pass.
#     625     """
# --> 626     return F.mse_loss(input, target, reduction=self.reduction)
#
# File ~/Documents/Year 3 Tuos/dissertation/Workspace/Experiment 1/.venv/lib/python3.13/site-packages/torch/nn/functional.py:3919, in mse_loss(input, target, size_average, reduce, reduction, weight)
#    3907 if has_torch_function_variadic(input, target, weight):
#    3908     return handle_torch_function(
#    3909         mse_loss,
#    3910         (input, target, weight),
#    (...)   3916         weight=weight,
#    3917     )
# -> 3919 if target.size() != input.size():
#    3920     warnings.warn(
#    3921         f"Using a target size ({target.size()}) that is different to the input size ({input.size()}). "
#    3922         "This will likely lead to incorrect results due to broadcasting. "
#    3923         "Please ensure they have the same size.",
#    3924         stacklevel=2,
#    3925     )
#    3927 if size_average is not None or reduce is not None:
#
# AttributeError: 'NoneType' object has no attribute 'size'

# %%
from src.evaluation import Evaluation
import matplotlib.pyplot as plt

actual_values = torch.Tensor(actual_values)
predicted_values = torch.Tensor(predicted_values)

evaluation = Evaluation(predicted_values, actual_values)
print(f"All metrics: {evaluation.compute_all_metrics()}")
evaluation.evaluation_plot().show()
# Out:
# All metrics: {'accuracy': 0.6744186046511628, 'Mean Squared Error': 0.013689035549759865, 'Mean Absolute Error': 0.09074100106954575, 'R^2': 0.7682884931564331}
